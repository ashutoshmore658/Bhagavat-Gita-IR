# %%
import nltk
from nltk import word_tokenize
from nltk.corpus import stopwords
import re
import numpy as np
import pandas as pd
import pickle
import numpy.linalg as lin
import unicodedata
import warnings 
from sklearn.cluster import KMeans
stop_words = set(stopwords.words('english'))
warnings.filterwarnings('ignore')

# %%
file=open('sentence.pkl','rb')
verse_embeddings_sentence=pickle.load(file)
file.close()
file=open('max.pkl','rb')
verse_embeddings_max=pickle.load(file)
file.close()
file=open('mean.pkl','rb')
verse_embeddings_mean=pickle.load(file)
file.close()

# %%
file=open('whole.pkl','rb')
verse_embeddings_whole=pickle.load(file)
file.close()

# %%
file=open('fasttext.pkl','rb')
fasttext=pickle.load(file)
file.close()

# %%
def remove_special_characters(text):
    regex = re.compile('[^a-zA-Z\s]')
    text_returned = re.sub(regex,' ',text)
    return text_returned

# %%
def strip_accents(s):
    return ''.join(c for c in unicodedata.normalize('NFD', s) if unicodedata.category(c) != 'Mn')

# %%
def word_embedding(word):
    word=word.lower()
    if word in fasttext.keys():
        return np.array(fasttext[word],dtype=np.float64)
    return np.array([0.0]*300)

# %%
def cosine_similarity(a,b):
    try:
        return a.dot(b)/(lin.norm(a)*lin.norm(b))
    except:
        return -1.0

# %%
def ed(a,b):
    return lin.norm(a-b)

# %%
def sentence_embedding(sentence):
    sentence=strip_accents(sentence)
    sentence=remove_special_characters(sentence)
    words=word_tokenize(sentence)
    if len(words)>0:
        words=[word  for word in words if word not in stop_words]
        sentence_embedding=[word_embedding(word) for word in words]
        return np.array(list(map(lambda x: sum(x)/len(x), zip(*sentence_embedding))))
    return np.array([0]*300)

# %%
data=pd.read_csv('../English.csv')

# %%
query='Importance of bhagavad gita'
query_embedding=sentence_embedding(query)
query_embedding_list=query_embedding.reshape(1,-1).astype(np.float64)

# %% [markdown]
# # Max Strategy

# %% [markdown]
# ## Cosine Similarity

# %%
def max_cosine(query_embedding,counter=10):
    scoring=[cosine_similarity(query_embedding,i) for i in verse_embeddings_max]
    verse_index=np.argsort(scoring)[-1::-1][:counter]
    return verse_index

# %%
verse_index=max_cosine(query_embedding)

# %%
data.loc[verse_index]
# Out:
#      Chapter  Verse                                              Sloke  \
# 583       18     64  सर्वगुह्यतमं भूय: श‍ृणु मे परमं वच: ।इष्टोऽसि ...
# 542       18     13  पञ्चैतानि महाबाहो कारणानि निबोध मे ।सांख्ये कृ...
# 370       10     37  वृष्णीनां वासुदेवोऽस्मि पाण्डवानां धनञ्जय: ।मु...
# 529       17     28  अश्रद्धया हुतं दत्तं तपस्तप्‍तं कृतं च यत् ।अस...
# 526       17     23  ॐ तत्सदिति निर्देशो ब्रह्मणस्त्रिविध: स्मृत: ।...
# 366       10     33  अक्षराणामकारोऽस्मि द्वन्द्व: सामासिकस्य च ।अहम...
# 491       15     19  यो मामेवमसम्मूढो जानाति पुरुषोत्तमम् ।स सर्ववि...
# 73         2     46  यावानर्थ उदपाने सर्वतः सम्प्लुतोदके ।तावान्सर्...
# 99         3      1  अर्जुन उवाचज्यायसी चेत्कर्मणस्ते मता बुद्धिर्ज...
# 432       13     16  बहिरन्तश्च भूतानामचरं चरमेव च ।सूक्ष्मत्वात्तद...
#
#                                             Commentary
# 583  The Lord has given Arjuna knowledge that is co...
# 542  A question may be raised that since any activi...
# 370  Kṛṣṇa is the original Supreme Personality of G...
# 529  Anything done without the transcendental objec...
# 526  It has been explained that penance, sacrifice,...
# 366  A-kāra, the first letter of the Sanskrit alpha...
# 491  There are many philosophical speculations abou...
# 73   The rituals and sacrifices mentioned in the ka...
# 99   The Supreme Personality of Godhead Śrī Kṛṣṇa h...
# 432  In Vedic literature we understand that Nārāyaṇ...

# %% [markdown]
# ## Euclidean Distance

# %%
def max_ed(query_embedding,counter=10):
    scoring=[ed(query_embedding,i) for i in verse_embeddings_max]
    verse_index=np.argsort(scoring)[:counter]
    return verse_index

# %%
verse_index=max_ed(query_embedding)

# %%
data.loc[verse_index]
# Out:
#      Chapter  Verse                                              Sloke  \
# 99         3      1  अर्जुन उवाचज्यायसी चेत्कर्मणस्ते मता बुद्धिर्ज...
# 370       10     37  वृष्णीनां वासुदेवोऽस्मि पाण्डवानां धनञ्जय: ।मु...
# 586       18     67  इदं ते नातपस्काय नाभक्ताय कदाचन ।न चाश‍ुश्रूषव...
# 3          1      4  अत्र श‍ूरा महेष्वासा भीमार्जुनसमा युधि ।युयुधा...
# 395       11     35  सञ्जय उवाचएतच्छ्रुत्वा वचनं केशवस्यकृताञ्जलिर्...
# 323        9     20  त्रैविद्या मां सोमपा: पूतपापायज्ञैरिष्ट्वा स्व...
# 319        9     16  अहं क्रतुरहं यज्ञ: स्वधाहमहमौषधम् ।मन्‍त्रोऽहम...
# 542       18     13  पञ्चैतानि महाबाहो कारणानि निबोध मे ।सांख्ये कृ...
# 552       18     23  नियतं सङ्गरहितमरागद्वेषत: कृतम् ।अफलप्रेप्सुना...
# 557       18     29  बुद्धेर्भेदं धृतेश्चैव गुणतस्त्रिविधं श‍ृणु ।प...
#
#                                             Commentary
# 99   The Supreme Personality of Godhead Śrī Kṛṣṇa h...
# 370  Kṛṣṇa is the original Supreme Personality of G...
# 586  Persons who have not undergone the austerities...
# 3    Even though Dhṛṣṭadyumna was not a very import...
# 395  As we have already explained, because of the s...
# 323  The word trai-vidyāḥ refers to the three Vedas...
# 319  The Vedic sacrifice known as Jyotiṣṭoma is als...
# 542  A question may be raised that since any activi...
# 552  Regulated occupational duties, as prescribed i...
# 557  Now after explaining knowledge, the object of ...

# %% [markdown]
# # Mean Pooling

# %% [markdown]
# ## Cosine Similarity

# %%
def mean_cosine(query_embedding,counter=10):
    scoring=[cosine_similarity(query_embedding,i) for i in verse_embeddings_mean]
    verse_index=np.argsort(scoring)[-1::-1][:counter]
    return verse_index

# %%
verse_index=mean_cosine(query_embedding)

# %%
data.loc[verse_index]
# Out:
#      Chapter  Verse                                              Sloke  \
# 527       17     24  तस्माद् ॐ इत्युदाहृत्य यज्ञदानतप:क्रिया: ।प्रव...
# 428       13      5  ऋषिभिर्बहुधा गीतं छन्दोभिर्विविधै: पृथक् ।ब्रह...
# 142        4      1  श्रीभगवानुवाचइमं विवस्वते योगं प्रोक्तवानहमव्य...
# 198        5     17  तद्बुद्धयस्तदात्मानस्तन्निष्ठास्तत्परायणा: ।गच...
# 530       18      1  सन्न्यासस्य महाबाहो तत्त्वमिच्छामि वेदितुम् ।त...
# 0          1      1  धृतराष्ट्र उवाचधर्मक्षेत्रे कुरुक्षेत्रे समवेत...
# 368       10     35  बृहत्साम तथा साम्न‍ां गायत्री छन्दसामहम् ।मासा...
# 487       15     15  सर्वस्य चाहं हृदि सन्निविष्टोमत्त: स्मृतिर्ज्ञ...
# 73         2     46  यावानर्थ उदपाने सर्वतः सम्प्लुतोदके ।तावान्सर्...
# 347       10     14  सर्वमेतदृतं मन्ये यन्मां वदसि केशव ।न हि ते भग...
#
#                                             Commentary
# 527  Oṁ tad viṣṇoḥ paramaṁ padam (Ṛg Veda 1.22.20)....
# 428  The Supreme Personality of Godhead, Kṛṣṇa, is ...
# 142  Herein we find the history of the Bhagavad-gīt...
# 198  The Supreme Transcendental Truth is Lord Kṛṣṇa...
# 530  Actually the Bhagavad-gītā is finished in seve...
# 0    Bhagavad-gītā is the widely read theistic scie...
# 368  It has already been explained by the Lord that...
# 487  The Supreme Lord is situated as Paramātmā in e...
# 73   The rituals and sacrifices mentioned in the ka...
# 347  Arjuna herein confirms that persons of faithle...

# %% [markdown]
# ## Euclidean Distance

# %%
def mean_ed(query_embedding,counter=10):
    scoring=[ed(query_embedding,i) for i in verse_embeddings_mean]
    verse_index=np.argsort(scoring)[:counter]
    return verse_index

# %%
verse_index=mean_ed(query_embedding)

# %%
data.loc[verse_index]
# Out:
#      Chapter  Verse                                              Sloke  \
# 226        6     27  प्रशान्तमनसं ह्येनं योगिनं सुखमुत्तमम् ।उपैति ...
# 347       10     14  सर्वमेतदृतं मन्ये यन्मां वदसि केशव ।न हि ते भग...
# 0          1      1  धृतराष्ट्र उवाचधर्मक्षेत्रे कुरुक्षेत्रे समवेत...
# 198        5     17  तद्बुद्धयस्तदात्मानस्तन्निष्ठास्तत्परायणा: ।गच...
# 142        4      1  श्रीभगवानुवाचइमं विवस्वते योगं प्रोक्तवानहमव्य...
# 581       18     62  तमेव शरणं गच्छ सर्वभावेन भारत ।तत्प्रसादात्परा...
# 527       17     24  तस्माद् ॐ इत्युदाहृत्य यज्ञदानतप:क्रिया: ।प्रव...
# 108        3     10  सहयज्ञाः प्रजाः सृष्ट्वा पुरोवाच प्रजापतिः ।अन...
# 323        9     20  त्रैविद्या मां सोमपा: पूतपापायज्ञैरिष्ट्वा स्व...
# 530       18      1  सन्न्यासस्य महाबाहो तत्त्वमिच्छामि वेदितुम् ।त...
#
#                                             Commentary
# 226  Brahma-bhūta is the state of being free from m...
# 347  Arjuna herein confirms that persons of faithle...
# 0    Bhagavad-gītā is the widely read theistic scie...
# 198  The Supreme Transcendental Truth is Lord Kṛṣṇa...
# 142  Herein we find the history of the Bhagavad-gīt...
# 581  A living entity should therefore surrender unt...
# 527  Oṁ tad viṣṇoḥ paramaṁ padam (Ṛg Veda 1.22.20)....
# 108  The material creation by the Lord of creatures...
# 323  The word trai-vidyāḥ refers to the three Vedas...
# 530  Actually the Bhagavad-gītā is finished in seve...

# %% [markdown]
# # Line Matching

# %% [markdown]
# ## Cosine Similarity

# %%
def line_cosine(query_embeddings,counter=10):
    scoring=[]
    for embeddings in verse_embeddings_sentence:
        score=[cosine_similarity(query_embedding,embed) for embed in embeddings]
        scoring.append(max(score))
    verse_index=np.argsort(scoring)[-1::-1][:counter]
    return verse_index

# %%
verse_index=line_cosine(query_embedding)
data.loc[verse_index]
# Out:
#      Chapter  Verse                                              Sloke  \
# 0          1      1  धृतराष्ट्र उवाचधर्मक्षेत्रे कुरुक्षेत्रे समवेत...
# 36         2      7  कार्पण्यदोषोपहतस्वभावःपृच्छामि त्वां धर्मसम्मू...
# 487       15     15  सर्वस्य चाहं हृदि सन्निविष्टोमत्त: स्मृतिर्ज्ञ...
# 346       10     11  तेषामेवानुकम्पार्थमहमज्ञानजं तम: ।नाशयाम्यात्म...
# 595       18     78  यत्र योगेश्वर: कृष्णो यत्र पार्थो धनुर्धर: ।तत...
# 41         2     12  न त्वेवाहं जातु नासं न त्वं नेमे जनाधिपाः ।न च...
# 270        7     24  अव्यक्तं व्यक्तिमापन्नं मन्यन्ते मामबुद्धय: ।प...
# 68         2     39  एषा तेऽभिहिता सांख्ये बुद्धिर्योगे त्विमां श‍ृ...
# 490       15     18  यस्मात्क्षरमतीतोऽहमक्षरादपि चोत्तम: ।अतोऽस्मि ...
# 142        4      1  श्रीभगवानुवाचइमं विवस्वते योगं प्रोक्तवानहमव्य...
#
#                                             Commentary
# 0    Bhagavad-gītā is the widely read theistic scie...
# 36   By nature’s own way the complete system of mat...
# 487  The Supreme Lord is situated as Paramātmā in e...
# 346  When Lord Caitanya was in Benares promulgating...
# 595  The Bhagavad-gītā began with an inquiry of Dhṛ...
# 41   In the Vedas – in the Kaṭha Upaniṣad as well a...
# 270  Those who are worshipers of demigods have been...
# 68   According to the Nirukti, or the Vedic diction...
# 490  No one can surpass the Supreme Personality of ...
# 142  Herein we find the history of the Bhagavad-gīt...

# %% [markdown]
# ## Euclidean Distance

# %%
def line_ed(query_embeddings,counter=10):
    scoring=[]
    for embeddings in verse_embeddings_sentence:
        score=[ed(query_embedding,embed) for embed in embeddings]
        scoring.append(max(score))
    verse_index=np.argsort(scoring)[:counter]
    return verse_index

# %%
verse_index=line_ed(query_embedding)
data.loc[verse_index]
# Out:
#      Chapter  Verse                                              Sloke  \
# 395       11     35  सञ्जय उवाचएतच्छ्रुत्वा वचनं केशवस्यकृताञ्जलिर्...
# 3          1      4  अत्र श‍ूरा महेष्वासा भीमार्जुनसमा युधि ।युयुधा...
# 552       18     23  नियतं सङ्गरहितमरागद्वेषत: कृतम् ।अफलप्रेप्सुना...
# 557       18     29  बुद्धेर्भेदं धृतेश्चैव गुणतस्त्रिविधं श‍ृणु ।प...
# 388       11     16  अनेकबाहूदरवक्‍त्रनेत्रंपश्यामि त्वां सर्वतोऽनन...
# 65         2     36  अवाच्यवादांश्च बहून्वदिष्यन्ति तवाहिताः ।निन्द...
# 583       18     64  सर्वगुह्यतमं भूय: श‍ृणु मे परमं वच: ।इष्टोऽसि ...
# 222        6     19  यथा दीपो निवातस्थो नेङ्गते सोपमा स्मृता ।योगिन...
# 320        9     17  पिताहमस्य जगतो माता धाता पितामह: ।वेद्यं पवित्...
# 189        5      6  सन्न्यासस्तु महाबाहो दु:खमाप्‍तुमयोगत: ।योगयुक...
#
#                                             Commentary
# 395  As we have already explained, because of the s...
# 3    Even though Dhṛṣṭadyumna was not a very import...
# 552  Regulated occupational duties, as prescribed i...
# 557  Now after explaining knowledge, the object of ...
# 388  Kṛṣṇa is the Supreme Personality of Godhead an...
# 65   Lord Kṛṣṇa was astonished in the beginning at ...
# 583  The Lord has given Arjuna knowledge that is co...
# 222  A truly Kṛṣṇa conscious person, always absorbe...
# 320  The entire cosmic manifestations, moving and n...
# 189  There are two classes of sannyāsīs, or persons...

# %% [markdown]
# # Whole Part

# %% [markdown]
# ## Cosine Similarity

# %%
def whole_cosine(query_embedding,counter=10):
    scoring=[cosine_similarity(query_embedding,i) for i in verse_embeddings_whole]
    verse_index=np.argsort(scoring)[-1::-1][:counter]
    return verse_index

# %%
verse_index=whole_cosine(query_embedding)
data.loc[verse_index]
# Out:
#      Chapter  Verse                                              Sloke  \
# 343       10      8  अहं सर्वस्य प्रभवो मत्त: सर्वं प्रवर्तते ।इति ...
# 487       15     15  सर्वस्य चाहं हृदि सन्निविष्टोमत्त: स्मृतिर्ज्ञ...
# 530       18      1  सन्न्यासस्य महाबाहो तत्त्वमिच्छामि वेदितुम् ।त...
# 428       13      5  ऋषिभिर्बहुधा गीतं छन्दोभिर्विविधै: पृथक् ।ब्रह...
# 73         2     46  यावानर्थ उदपाने सर्वतः सम्प्लुतोदके ।तावान्सर्...
# 527       17     24  तस्माद् ॐ इत्युदाहृत्य यज्ञदानतप:क्रिया: ।प्रव...
# 347       10     14  सर्वमेतदृतं मन्ये यन्मां वदसि केशव ।न हि ते भग...
# 142        4      1  श्रीभगवानुवाचइमं विवस्वते योगं प्रोक्तवानहमव्य...
# 253        7      7  मत्त: परतरं नान्यत्किञ्चिदस्ति धनञ्जय ।मयि सर्...
# 108        3     10  सहयज्ञाः प्रजाः सृष्ट्वा पुरोवाच प्रजापतिः ।अन...
#
#                                             Commentary
# 343  A learned scholar who has studied the Vedas pe...
# 487  The Supreme Lord is situated as Paramātmā in e...
# 530  Actually the Bhagavad-gītā is finished in seve...
# 428  The Supreme Personality of Godhead, Kṛṣṇa, is ...
# 73   The rituals and sacrifices mentioned in the ka...
# 527  Oṁ tad viṣṇoḥ paramaṁ padam (Ṛg Veda 1.22.20)....
# 347  Arjuna herein confirms that persons of faithle...
# 142  Herein we find the history of the Bhagavad-gīt...
# 253  There is a common controversy over whether the...
# 108  The material creation by the Lord of creatures...

# %% [markdown]
# ## Euclidean Distance

# %%
def whole_ed(query_embedding,counter=10):
    scoring=[cosine_similarity(query_embedding,i) for i in verse_embeddings_whole]
    verse_index=np.argsort(scoring)[:counter]
    return verse_index

# %%
verse_index=whole_ed(query_embedding)
data.loc[verse_index]
# Out:
#      Chapter  Verse                                              Sloke  \
# 364       10     31  पवन: पवतामस्मि राम: शस्त्रभृतामहम् ।झषाणां मकर...
# 538       18      9  कार्यमित्येव यत्कर्म नियतं क्रियतेऽर्जुन ।सङ्ग...
# 5          1      9  अन्ये च बहवः श‍ूरा मदर्थे त्यक्तजीविताः ।नानाश...
# 402       11     44  तस्मात्प्रणम्य प्रणिधाय कायंप्रसादये त्वामहमीश...
# 222        6     19  यथा दीपो निवातस्थो नेङ्गते सोपमा स्मृता ।योगिन...
# 369       10     36  द्यूतं छलयतामस्मि तेजस्तेजस्विनामहम् ।जयोऽस्मि...
# 16         1     26  तत्रापश्यत्स्थितान्पार्थः पितॄनथ पितामहान्।आचा...
# 541       18     12  अनिष्टमिष्टं मिश्रं च त्रिविधं कर्मण: फलम् ।भव...
# 555       18     27  रागी कर्मफलप्रेप्सुर्लुब्धो हिंसात्मकोऽश‍ुचि: ...
# 204        5     23  शक्न‍ोतीहैव य: सोढुं प्राक्शरीरविमोक्षणात् ।का...
#
#                                             Commentary
# 364  Of all the aquatics the shark is one of the bi...
# 538  Prescribed duties must be performed with this ...
# 5    As far as the others are concerned – like Jaya...
# 402  Kṛṣṇa’s devotees relate to Kṛṣṇa in various re...
# 222  A truly Kṛṣṇa conscious person, always absorbe...
# 369  There are many kinds of cheaters all over the ...
# 16   On the battlefield Arjuna could see all kinds ...
# 541  A person in Kṛṣṇa consciousness acting in know...
# 555  A person is too much attached to a certain kin...
# 204  If one wants to make steady progress on the pa...

# %% [markdown]
# # Clustering

# %% [markdown]
# ## Max Pooling

# %%
kmeans_max = KMeans(n_clusters=60, random_state=0).fit(verse_embeddings_max)

# %%
def kmeans_max_cluster(query_embedding_list):
    label=kmeans_max.predict(query_embedding_list)[0]
    verse_index=[i for i in range(len(data)) if kmeans_max.labels_[i]==label]
    return verse_index

# %%
verse_index=kmeans_max_cluster(query_embedding_list)
data.loc[verse_index]
# Out:
#      Chapter  Verse                                              Sloke  \
# 20         1     31  न च श्रेयोऽनुपश्यामि हत्वा स्वजनमाहवे ।न काङ्क...
# 46         2     17  अविनाशि तु तद्विद्धि येन सर्वमिदं ततम् ।विनाशम...
#
#                                             Commentary
# 20   Without knowing that one’s self-interest is in...
# 46   This verse more clearly explains the real natu...
# 57   Accepting that there are two classes of philos...
# 99   The Supreme Personality of Godhead Śrī Kṛṣṇa h...
# 118  Kings like Janaka were all self-realized souls...
# 149  According to Bhagavad-gītā, a sādhu (holy man)...
# 153  There is a great misconception about the gods ...
# 171  From the foregoing explanation of different ty...
# 189  There are two classes of sannyāsīs, or persons...
# 218  The ultimate goal in practicing yoga is now cl...
# 243  Advanced yogīs are not very much attracted to ...
# 251  Here it is clearly mentioned that living entit...
# 275  Birth, death, old age and diseases affect this...
# 289  It is clearly stated here that oṁ, Brahman and...
# 294  The less intelligent, who try to remain within...
# 318  This verse is the summary of the previous vers...
# 351  A similar statement was made to Sūta Gosvāmī b...
# 357  Indra is the chief demigod of the heavenly pla...
# 362  Among the many-hooded Nāga serpents, Ananta is...
# 363  Diti and Aditi are two sisters. The sons of Ad...
# 365  Among the created manifestations, the first is...
# 368  It has already been explained by the Lord that...
# 370  Kṛṣṇa is the original Supreme Personality of G...
# 391  The demigods in all the planetary systems fear...
# 401  The Supreme Personality of Godhead, Kṛṣṇa, is ...
# 412  Kṛṣṇa can be understood only by the process of...
# 426  While discussing the subject of the body and t...
# 446  This body is made by material nature under the...
# 457  The living entities conditioned by material na...
# 467  The result of pious activities in the mode of ...
# 478  The spiritual world, the abode of the Supreme ...
# 533  Although there are differences of opinion abou...

# %% [markdown]
# ## Mean Pooling

# %%
kmeans_mean = KMeans(n_clusters=60, random_state=0).fit(verse_embeddings_mean)

# %%
def kmeans_mean_cluster(query_embedding_list):
    label=kmeans_mean.predict(query_embedding_list)[0]
    verse_index=[i for i in range(len(data)) if kmeans_mean.labels_[i]==label]
    return verse_index

# %%
verse_index=kmeans_mean_cluster(query_embedding_list)
data.loc[verse_index]
# Out:
#      Chapter  Verse                                              Sloke  \
# 226        6     27  प्रशान्तमनसं ह्येनं योगिनं सुखमुत्तमम् ।उपैति ...
#
#                                             Commentary
# 226  Brahma-bhūta is the state of being free from m...

# %% [markdown]
# ## Whole

# %%
kmeans_whole = KMeans(n_clusters=60, random_state=0).fit(verse_embeddings_whole)

# %%
def kmeans_whole_cluster(query_embedding_list):
    label=kmeans_whole.predict(query_embedding_list)[0]
    verse_index=[i for i in range(len(data)) if kmeans_whole.labels_[i]==label]
    return verse_index

# %%
verse_index=kmeans_whole_cluster(query_embedding_list)
data.loc[verse_index]
# Out:
#      Chapter  Verse                                              Sloke  \
# 31         2      2  श्री भगवानुवाचकुतस्त्वा कश्मलमिदं विषमे समुपस्...
# 71         2     44  भोगैश्वर्यप्रसक्तानां तयापहृतचेतसाम् ।व्यवसाया...
# 108        3     10  सहयज्ञाः प्रजाः सृष्ट्वा पुरोवाच प्रजापतिः ।अन...
# 198        5     17  तद्बुद्धयस्तदात्मानस्तन्निष्ठास्तत्परायणा: ।गच...
