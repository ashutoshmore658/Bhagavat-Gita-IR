# %% [markdown]
# **Libraries Required**

# %%
import numpy as np
import pandas as pd
from sentence_transformers import SentenceTransformer
from nltk import sent_tokenize
import nltk
from numpy import linalg as lin
import re
import pickle
from sklearn.cluster import KMeans

# %%
model = SentenceTransformer('multi-qa-mpnet-base-dot-v1')

# %%
def cosine_similarity(a,b):
    try:
        return a.dot(b)/(lin.norm(a)*lin.norm(b))
    except:
        return -1.0

# %%
def ed(a,b):
    return lin.norm(a-b)

# %%
data=pd.read_csv('../hindi.csv')

# %%
file=open('sentence.pkl','rb')
verse_embeddings_sentence=pickle.load(file)
file.close()
file=open('max.pkl','rb')
verse_embeddings_max=pickle.load(file)
file.close()
file=open('mean.pkl','rb')
verse_embeddings_mean=pickle.load(file)
file.close()

# %%
file=open('whole.pkl','rb')
verse_embeddings_whole=pickle.load(file)
file.close()

# %%
query='importace of bhagavat gita'
query_embedding=model.encode(query)
query_embedding_list=query_embedding.reshape(1,-1).astype(np.float64)

# %% [markdown]
# # Max Strategy

# %% [markdown]
# ## Cosine Similarity

# %%
def max_cosine(query_embedding,counter=10):
    scoring=[cosine_similarity(query_embedding,i) for i in verse_embeddings_max]
    verse_index=np.argsort(scoring)[-1::-1][:counter]
    return verse_index

# %%
verse_index=max_cosine(query_embedding)
data.loc[verse_index]
# Out:
#      Chapter  Verse                                              Sloke  \
# 614       17     26  सद्भावे साधुभावे च सदित्येतत्प्रयुज्यते।प्रशस्...
# 615       17     27  यज्ञे तपसि दाने च स्थितिः सदिति चोच्यते।कर्म च...
# 428       11     20  द्यावापृथिव्योरिदमन्तरं हि\n\nव्याप्तं त्वयैके...
# 400       10     34  मृत्युः सर्वहरश्चाहमुद्भवश्च भविष्यताम्।\n\nकी...
# 336        9      4  मया ततमिदं सर्वं जगदव्यक्तमूर्तिना।\n\nमत्स्था...
# 408       10     42  अथवा बहुनैतेन किं ज्ञातेन तवार्जुन।\n\nविष्टभ्...
# 196        4     40  अज्ञश्चाश्रद्दधानश्च संशयात्मा विनश्यति।\n\nना...
# 286        7     12  ये चैव सात्त्विका भावा राजसास्तामसाश्च ये।\n\n...
# 564       15     20  इति गुह्यतमं शास्त्रमिदमुक्तं मयाऽनघ।एतद्बुद्ध...
# 592       17      4  यजन्ते सात्त्विका देवान्यक्षरक्षांसि राजसाः।प्...
#
#                                             Commentary
# 614  अब श्रीकृष्ण 'सत्' शब्द की मांगलिकता की महिमा ...
# 615  अब श्रीकृष्ण 'सत्' शब्द की मांगलिकता की महिमा ...
# 428  अर्जुन कहता है कि हे सर्वव्यापी भगवान! आप सारी...
# 400   अंग्रेजी में एक कहावत है 'मृत्यु के समान अटल'...
# 336   वैदिक दर्शन इस अवधारणा को स्वीकार नहीं करता क...
# 408  श्रीकृष्ण का उपर्युक्त कथन यह इंगित करता है कि...
# 196  भक्ति रसामृत सिंधु में साधकों को उनकी श्रद्धा ...
# 286  पिछले चार श्लोकों में अपनी महिमा का वर्णन करने...
# 564  इस अध्याय का अंतिम श्लोक 'इति' शब्द से प्रारंभ...
# 592  ऐसा कहा गया है कि सज्जन व्यक्ति अच्छाई की ओर त...

# %% [markdown]
# ## Euclidean Distance

# %%
def max_ed(query_embedding,counter=10):
    scoring=[ed(query_embedding,i) for i in verse_embeddings_max]
    verse_index=np.argsort(scoring)[:counter]
    return verse_index

# %%
verse_index=max_ed(query_embedding)
data.loc[verse_index]
# Out:
#      Chapter  Verse                                              Sloke  \
# 564       15     20  इति गुह्यतमं शास्त्रमिदमुक्तं मयाऽनघ।एतद्बुद्ध...
# 614       17     26  सद्भावे साधुभावे च सदित्येतत्प्रयुज्यते।प्रशस्...
# 615       17     27  यज्ञे तपसि दाने च स्थितिः सदिति चोच्यते।कर्म च...
# 400       10     34  मृत्युः सर्वहरश्चाहमुद्भवश्च भविष्यताम्।\n\nकी...
# 592       17      4  यजन्ते सात्त्विका देवान्यक्षरक्षांसि राजसाः।प्...
# 21         1     25  भीष्मद्रोणप्रमुखतः सर्वेषां च महीक्षिताम्।\n\n...
# 428       11     20  द्यावापृथिव्योरिदमन्तरं हि\n\nव्याप्तं त्वयैके...
# 423       11     15  अर्जुन उवाच\n\nपश्यामि देवांस्तव देव देहे\n\nस...
# 93         2     52  यदा ते मोहकलिलं बुद्धिर्व्यतितरिष्यति।\n\nतदा ...
# 24         1     28  अर्जुन उवाच\n\nकृपया परयाऽऽविष्टो विषीदन्निदमब...
#
#                                             Commentary
# 564  इस अध्याय का अंतिम श्लोक 'इति' शब्द से प्रारंभ...
# 614  अब श्रीकृष्ण 'सत्' शब्द की मांगलिकता की महिमा ...
# 615  अब श्रीकृष्ण 'सत्' शब्द की मांगलिकता की महिमा ...
# 400   अंग्रेजी में एक कहावत है 'मृत्यु के समान अटल'...
# 592  ऐसा कहा गया है कि सज्जन व्यक्ति अच्छाई की ओर त...
# 21    "कुरु" शब्द का प्रयोग कौरवों और पाण्डवों दोनो...
# 428  अर्जुन कहता है कि हे सर्वव्यापी भगवान! आप सारी...
# 423   अर्जुन ने कहा कि स्वर्गलोक सहित मैं तीनों लोक...
# 93   श्रीकृष्ण ने पहले के श्लोकों मे स्पष्ट किया है...
# 24   आसक्ति लौकिक या आध्यात्मिक मनोभावना हो सकती है...

# %% [markdown]
# # Mean Pooling

# %% [markdown]
# ## Cosine Similarity

# %%
def mean_cosine(query_embedding,counter=10):
    scoring=[cosine_similarity(query_embedding,i) for i in verse_embeddings_mean]
    verse_index=np.argsort(scoring)[-1::-1][:counter]
    return verse_index

# %%
verse_index=mean_cosine(query_embedding)
data.loc[verse_index]
# Out:
#      Chapter  Verse                                              Sloke  \
# 462       11     54  भक्त्या त्वनन्यया शक्यमहमेवंविधोऽर्जुन।\n\nज्ञ...
# 128        3     15  कर्म ब्रह्मोद्भवं विद्धि ब्रह्माक्षरसमुद्भवम्।...
# 380       10     14  सर्वमेतदृतं मन्ये यन्मां वदसि केशव।\n\nन हि ते...
# 159        4      3  स एवायं मया तेऽद्य योगः प्रोक्तः पुरातनः।\n\nभ...
# 344        9     12  मोघाशा मोघकर्माणो मोघज्ञाना विचेतसः।\n\nराक्षस...
# 430       11     22  रुद्रादित्या वसवो ये च साध्या\n\nविश्वेऽश्िवनौ...
# 381       10     15  स्वयमेवात्मनाऽत्मानं वेत्थ त्वं पुरुषोत्तम।\n\...
# 228        6      1  श्री भगवानुवाच\n\nअनाश्रितः कर्मफलं कार्यं कर्...
# 337        9      5  न च मत्स्थानि भूतानि पश्य मे योगमैश्वरम्।\n\nभ...
# 423       11     15  अर्जुन उवाच\n\nपश्यामि देवांस्तव देव देहे\n\nस...
#
#                                             Commentary
# 462  इस श्लोक में भी श्रीकृष्ण इस पर बल देते हैं कि...
# 128   वेद भगवान की श्वास से प्रकट हुए हैं। अरेऽस्य ...
# 380   भगवान के दिव्य ऐश्वर्य और अनन्त महिमा को ध्या...
# 159  श्रीकृष्ण अर्जुन को बताते हैं कि उसे दिया जा र...
# 344  भगवान के साकार रूप के सम्बन्ध में नास्तिक विचा...
# 430   ये सभी महान विभूतियाँ भगवान की शक्ति से ही अप...
# 381  श्रीकृष्ण के दिव्य पुरुषोत्तम स्वरूप के महत्त्...
# 228  वेदों में वर्णित धार्मिक अनुष्ठान की गतिविधियो...
# 337   पिछले श्लोक में कथित रूप से उल्लिखित दो शक्ति...
# 423   अर्जुन ने कहा कि स्वर्गलोक सहित मैं तीनों लोक...

# %% [markdown]
# ## Euclidean Distance

# %%
def mean_ed(query_embedding,counter=10):
    scoring=[ed(query_embedding,i) for i in verse_embeddings_mean]
    verse_index=np.argsort(scoring)[:counter]
    return verse_index

# %%
verse_index=mean_ed(query_embedding)

# %%
data.loc[verse_index]
# Out:
#      Chapter  Verse                                              Sloke  \
# 462       11     54  भक्त्या त्वनन्यया शक्यमहमेवंविधोऽर्जुन।\n\nज्ञ...
# 278        7      4  भूमिरापोऽनलो वायुः खं मनो बुद्धिरेव च।\n\nअहङ्...
# 128        3     15  कर्म ब्रह्मोद्भवं विद्धि ब्रह्माक्षरसमुद्भवम्।...
# 87         2     46  यावानर्थ उदपाने सर्वतः संप्लुतोदके।\n\nतावान्स...
# 196        4     40  अज्ञश्चाश्रद्दधानश्च संशयात्मा विनश्यति।\n\nना...
# 445       11     37  कस्माच्च ते न नमेरन्महात्मन्\n\nगरीयसे ब्रह्मण...
# 344        9     12  मोघाशा मोघकर्माणो मोघज्ञाना विचेतसः।\n\nराक्षस...
# 48         2      7  कार्पण्यदोषोपहतस्वभावः\n\nपृच्छामि त्वां धर्मस...
# 381       10     15  स्वयमेवात्मनाऽत्मानं वेत्थ त्वं पुरुषोत्तम।\n\...
# 180        4     24  ब्रह्मार्पणं ब्रह्महविर्ब्रह्माग्नौ ब्रह्मणा ह...
#
#                                             Commentary
# 462  इस श्लोक में भी श्रीकृष्ण इस पर बल देते हैं कि...
# 278  प्राकृत शक्ति से रचित संसार विचित्र, जटिल और अ...
# 128   वेद भगवान की श्वास से प्रकट हुए हैं। अरेऽस्य ...
# 87   वेदों में एक लाख मंत्रों का उल्लेख किया गया है...
# 196  भक्ति रसामृत सिंधु में साधकों को उनकी श्रद्धा ...
# 445  अर्जुन ने इस श्लोक में कस्माच्च तेन शब्द का प्...
# 344  भगवान के साकार रूप के सम्बन्ध में नास्तिक विचा...
# 48   भगवद्गीता का यह क्षण अत्यंत महत्त्वपूर्ण है। ज...
# 381  श्रीकृष्ण के दिव्य पुरुषोत्तम स्वरूप के महत्त्...
# 180   वास्तव में संसार के पदार्थ भगवान की माया शक्त...

# %% [markdown]
# # Line Matching

# %% [markdown]
# ## Cosine Similarity

# %%
def line_cosine(query_embeddings,counter=10):
    scoring=[]
    for embeddings in verse_embeddings_sentence:
        score=[cosine_similarity(query_embedding,embed) for embed in embeddings]
        scoring.append(max(score))
    verse_index=np.argsort(scoring)[-1::-1][:counter]
    return verse_index

# %%
verse_index=line_cosine(query_embedding)
data.loc[verse_index]
# Out:
#      Chapter  Verse                                              Sloke  \
# 487       13      5  ऋषिभिर्बहुधा गीतं छन्दोभिर्विविधैः पृथक्।ब्रह्...
# 126        3     13  यज्ञशिष्टाशिनः सन्तो मुच्यन्ते सर्वकिल्बिषैः।\...
# 164        4      8  परित्राणाय साधूनां विनाशाय च दुष्कृताम्।\n\nधर...
# 626       18     10  न द्वेष्ट्यकुशलं कर्म कुशले नानुषज्जते।त्यागी ...
# 556       15     12  यदादित्यगतं तेजो जगद्भासयतेऽखिलम्।यच्चन्द्रमसि...
# 408       10     42  अथवा बहुनैतेन किं ज्ञातेन तवार्जुन।\n\nविष्टभ्...
# 614       17     26  सद्भावे साधुभावे च सदित्येतत्प्रयुज्यते।प्रशस्...
# 615       17     27  यज्ञे तपसि दाने च स्थितिः सदिति चोच्यते।कर्म च...
# 200        5      2  श्री भगवानुवाच\n\nसंन्यासः कर्मयोगश्च निःश्रेय...
# 157        4      1  श्री भगवानुवाच\n\nइमं विवस्वते योगं प्रोक्तवान...
#
#                                             Commentary
# 487  ज्ञान बुद्धि को तभी आकर्षित करता है जब उसकी अभ...
# 126  वैदिक परम्परा में भोजन इस भावना से बनाया जाता ...
# 164  पिछले श्लोक में यह कहने के पश्चात कि भगवान संस...
# 626  सात्विक त्याग में स्थित लोग प्रतिकूल परिस्थिति...
# 556  मानवीय स्वभाव ऐसा है कि हमें जो महत्वपूर्ण प्र...
# 408  श्रीकृष्ण का उपर्युक्त कथन यह इंगित करता है कि...
# 614  अब श्रीकृष्ण 'सत्' शब्द की मांगलिकता की महिमा ...
# 615  अब श्रीकृष्ण 'सत्' शब्द की मांगलिकता की महिमा ...
# 200  इस श्लोक में श्रीकृष्ण ने कर्म संन्यास और कर्म...
# 157  किसी मनुष्य को केवल अमूल्य ज्ञान प्रदान करना ह...

# %% [markdown]
# ## Euclidean Distance

# %%
def line_ed(query_embeddings,counter=10):
    scoring=[]
    for embeddings in verse_embeddings_sentence:
        score=[ed(query_embedding,embed) for embed in embeddings]
        scoring.append(max(score))
    verse_index=np.argsort(scoring)[:counter]
    return verse_index

# %%
verse_index=line_ed(query_embedding)
data.loc[verse_index]
# Out:
#      Chapter  Verse                                              Sloke  \
# 430       11     22  रुद्रादित्या वसवो ये च साध्या\n\nविश्वेऽश्िवनौ...
# 423       11     15  अर्जुन उवाच\n\nपश्यामि देवांस्तव देव देहे\n\nस...
# 109        2     68  तस्माद्यस्य महाबाहो निगृहीतानि सर्वशः।\n\nइन्द...
# 607       17     19  मूढग्राहेणात्मनो यत्पीडया क्रियते तपः।परस्योत्...
# 10         1     13  ततः शङ्खाश्च भेर्यश्च पणवानकगोमुखाः।\n\nसहसैवा...
# 38         1     43  दोषैरेतैः कुलघ्नानां वर्णसङ्करकारकैः।\n\nउत्सा...
# 3          1      4  अत्र शूरा महेष्वासा भीमार्जुनसमा युधि।\n\nयुयु...
# 4          1      5  धृष्टकेतुश्चेकितानः काशिराजश्च वीर्यवान्।\n\nप...
# 5          1      6  युधामन्युश्च विक्रान्त उत्तमौजाश्च वीर्यवान्।\...
# 9          1     12  तस्य संजनयन्हर्षं कुरुवृद्धः पितामहः।\n\nसिंहन...
#
#                                             Commentary
# 430   ये सभी महान विभूतियाँ भगवान की शक्ति से ही अप...
# 423   अर्जुन ने कहा कि स्वर्गलोक सहित मैं तीनों लोक...
# 109   प्रबुद्ध आत्माएँ लोकातीत अर्थात दिव्य ज्ञान द...
# 607  मूढग्राहेणात्मनो शब्द ऐसे व्यक्तियों के लिए प्...
# 10   युद्ध के लिए भीष्म पितामह के तीव्र उत्साह को द...
# 38   सनातन-धर्म या वर्णाश्रम द्वारा निर्धारित मानव ...
# 3    अपने सम्मख संकट को मंडराते देखकर दुर्योधन को प...
# 4    अपने सम्मख संकट को मंडराते देखकर दुर्योधन को प...
# 5    अपने सम्मख संकट को मंडराते देखकर दुर्योधन को प...
# 9    भीष्म पितामह अपने भतीजे दुर्योधन के भीतर के भय...

# %% [markdown]
# # Whole Part

# %% [markdown]
# ## Cosine Similarity

# %%
def whole_cosine(query_embedding,counter=10):
    scoring=[cosine_similarity(query_embedding,i) for i in verse_embeddings_whole]
    verse_index=np.argsort(scoring)[-1::-1][:counter]
    return verse_index

# %%
verse_index=whole_cosine(query_embedding)
data.loc[verse_index]
# Out:
#      Chapter  Verse                                              Sloke  \
# 213        5     15  नादत्ते कस्यचित्पापं न चैव सुकृतं विभुः।\n\nअज...
# 640       18     24  यत्तु कामेप्सुना कर्म साहङ्कारेण वा पुनः।क्रिय...
# 599       17     11  अफलाकाङ्क्षिभिर्यज्ञो विधिदृष्टो य इज्यते।यष्ट...
# 344        9     12  मोघाशा मोघकर्माणो मोघज्ञाना विचेतसः।\n\nराक्षस...
# 288        7     14  दैवी ह्येषा गुणमयी मम माया दुरत्यया।\n\nमामेव ...
# 542       14     25  मानापमानयोस्तुल्यस्तुल्यो मित्रारिपक्षयोः।सर्व...
# 541       14     24  समदुःखसुखः स्वस्थः समलोष्टाश्मकाञ्चनः।तुल्यप्र...
# 380       10     14  सर्वमेतदृतं मन्ये यन्मां वदसि केशव।\n\nन हि ते...
# 392       10     26  अश्वत्थः सर्ववृक्षाणां देवर्षीणां च नारदः।\n\n...
# 496       13     14  सर्वतः पाणिपादं तत्सर्वतोऽक्षिशिरोमुखम्।सर्वतः...
#
#                                             Commentary
# 213   भगवान किसी के पुण्य या पापकर्मों के लिए उत्तर...
# 640  रजोगुण की प्रवृत्ति ऐसी होती है जो भौतिक इच्छा...
# 599  यज्ञ की प्रकृति भी तीन गुणों के सदृश है। श्रीक...
# 344  भगवान के साकार रूप के सम्बन्ध में नास्तिक विचा...
# 288  कुछ लोग यह स्वीकार करते हैं कि भौतिक शक्ति मिथ...
# 542  भगवान के समान आत्मा भी तीनों गुणों से परे है। ...
# 541  भगवान के समान आत्मा भी तीनों गुणों से परे है। ...
# 380   भगवान के दिव्य ऐश्वर्य और अनन्त महिमा को ध्या...
# 392   बरगद के वृक्ष के नीचे बैठने वालों को शीतलता क...
# 496  प्रायः लोग तर्क देते हैं कि भगवान के हाथ, पैर,...

# %% [markdown]
# ## Euclidean Distance

# %%
def whole_ed(query_embedding,counter=10):
    scoring=[cosine_similarity(query_embedding,i) for i in verse_embeddings_whole]
    verse_index=np.argsort(scoring)[:counter]
    return verse_index

# %%
verse_index=whole_ed(query_embedding)
data.loc[verse_index]
# Out:
#      Chapter  Verse                                              Sloke  \
# 486       13      4  तत्क्षेत्रं यच्च यादृक् च यद्विकारि यतश्च यत्।...
# 439       11     31  आख्याहि मे को भवानुग्ररूपो\n\nनमोऽस्तु ते देवव...
# 71         2     30  देही नित्यमवध्योऽयं देहे सर्वस्य भारत।\n\nतस्म...
# 368       10      2  न मे विदुः सुरगणाः प्रभवं न महर्षयः।\n\nअहमादि...
# 322        8     18  अव्यक्ताद्व्यक्तयः सर्वाः प्रभवन्त्यहरागमे।\n\...
# 241        6     14  प्रशान्तात्मा विगतभीर्ब्रह्मचारिव्रते स्थितः।\...
# 448       11     40  नमः पुरस्तादथ पृष्ठतस्ते\n\nनमोऽस्तु ते सर्वत ...
# 452       11     44  तस्मात्प्रणम्य प्रणिधाय कायं\n\nप्रसादये त्वाम...
# 457       11     49  मा ते व्यथा मा च विमूढभावो\n\nदृष्ट्वा रूपं घो...
# 137        3     24  उत्सीदेयुरिमे लोका न कुर्यां कर्म चेदहम्।\n\nस...
#
#                                             Commentary
# 486  श्रीकृष्ण अब स्वयं कई प्रश्न खड़े करते हैं और ...
# 439  इससे पूर्व अर्जुन ने भगवान का विश्वरूप देखने क...
# 71   अपने उपदेशों के अंतर्गत भगवान श्रीकृष्ण प्रायः...
# 368  न तो स्वर्ग के देवता और न ही महान ऋषि मेरी उत्...
# 322  ब्रह्माण्ड के अद्भुत ब्रह्माण्डीय खेल में विभि...
# 241  श्रीकृष्ण साधना में सफलता के लिए ब्रह्मचर्य का...
# 448  अर्जुन श्रीकृष्ण की महिमा का निरन्तर गान करते ...
# 452   अपने व्यवहार को भगवान के प्रति अपराध मानते हु...
# 457  श्रीकृष्ण निरन्तर अर्जुन को धीरज बंधाते हुए कह...
# 137  जब श्रीकृष्ण धरती पर मनुष्य के रूप में प्रकट ह...

# %% [markdown]
# # Clustering

# %% [markdown]
# ## Max Embedding

# %%
kmeans_max = KMeans(n_clusters=60, random_state=0).fit(verse_embeddings_max)

# %%
def kmeans_max_cluster(query_embedding_list):
    label=kmeans_max.predict(query_embedding_list)[0]
    verse_index=[i for i in range(len(data)) if kmeans_max.labels_[i]==label]
    return verse_index

# %%
verse_index=kmeans_max_cluster(query_embedding_list)
data.loc[verse_index]
# Out:
#      Chapter  Verse                                              Sloke  \
# 284        7     10  बीजं मां सर्वभूतानां विद्धि पार्थ सनातनम्।\n\n...
# 286        7     12  ये चैव सात्त्विका भावा राजसास्तामसाश्च ये।\n\n...
# 380       10     14  सर्वमेतदृतं मन्ये यन्मां वदसि केशव।\n\nन हि ते...
# 397       10     31  पवनः पवतामस्मि रामः शस्त्रभृतामहम्।\n\nझषाणां ...
# 454       11     46  किरीटिनं गदिनं चक्रहस्त\n\nमिच्छामि त्वां द्रष...
# 614       17     26  सद्भावे साधुभावे च सदित्येतत्प्रयुज्यते।प्रशस्...
# 615       17     27  यज्ञे तपसि दाने च स्थितिः सदिति चोच्यते।कर्म च...
#
#                                             Commentary
# 284  कारण को ही अपने फल के बीज के रूप में जाना जाता...
# 286  पिछले चार श्लोकों में अपनी महिमा का वर्णन करने...
# 380   भगवान के दिव्य ऐश्वर्य और अनन्त महिमा को ध्या...
# 397  प्रकृति में वायु अति प्रभावी ढंग से शुद्धिकरण ...
# 454  श्रीकृष्ण की विशेष कृपा से अर्जुन भगवान का विश...
# 614  अब श्रीकृष्ण 'सत्' शब्द की मांगलिकता की महिमा ...
# 615  अब श्रीकृष्ण 'सत्' शब्द की मांगलिकता की महिमा ...

# %% [markdown]
# ## Mean Embedding

# %%
kmeans_mean = KMeans(n_clusters=60, random_state=0).fit(verse_embeddings_mean)

# %%
def kmeans_mean_cluster(query_embedding_list):
    label=kmeans_mean.predict(query_embedding_list)[0]
    verse_index=[i for i in range(len(data)) if kmeans_mean.labels_[i]==label]
    return verse_index

# %%
verse_index=kmeans_mean_cluster(query_embedding_list)
data.loc[verse_index]
# Out:
#      Chapter  Verse                                              Sloke  \
# 128        3     15  कर्म ब्रह्मोद्भवं विद्धि ब्रह्माक्षरसमुद्भवम्।...
# 159        4      3  स एवायं मया तेऽद्य योगः प्रोक्तः पुरातनः।\n\nभ...
# 180        4     24  ब्रह्मार्पणं ब्रह्महविर्ब्रह्माग्नौ ब्रह्मणा ह...
# 274        6     47  योगिनामपि सर्वेषां मद्गतेनान्तरात्मना।\n\nश्रद...
# 279        7      5  अपरेयमितस्त्वन्यां प्रकृतिं विद्धि मे पराम्।\n...
# 300        7     26  वेदाहं समतीतानि वर्तमानानि चार्जुन।\n\nभविष्या...
# 338        9      6  यथाऽऽकाशस्थितो नित्यं वायुः सर्वत्रगो महान्।\n...
# 385       10     19  श्री भगवानुवाच\n\nहन्त ते कथयिष्यामि दिव्या ह्...
# 386       10     20  अहमात्मा गुडाकेश सर्वभूताशयस्थितः।\n\nअहमादिश्...
# 390       10     24  पुरोधसां च मुख्यं मां विद्धि पार्थ बृहस्पतिम्।...
# 417       11      9  सञ्जय उवाच\n\nएवमुक्त्वा ततो राजन्महायोगेश्वरो...
# 431       11     23  रूपं महत्ते बहुवक्त्रनेत्रं\n\nमहाबाहो बहुबाहू...
# 438       11     30  लेलिह्यसे ग्रसमानः समन्ता\n\nल्लोकान्समग्रान्व...
# 445       11     37  कस्माच्च ते न नमेरन्महात्मन्\n\nगरीयसे ब्रह्मण...
# 446       11     38  त्वमादिदेवः पुरुषः पुराण\n\nस्त्वमस्य विश्वस्य...
# 453       11     45  अदृष्टपूर्वं हृषितोऽस्मि दृष्ट्वा\n\nभयेन च प्...
# 462       11     54  भक्त्या त्वनन्यया शक्यमहमेवंविधोऽर्जुन।\n\nज्ञ...
# 500       13     18  ज्योतिषामपि तज्ज्योतिस्तमसः परमुच्यते।ज्ञानं ज...
#
#                                             Commentary
# 128   वेद भगवान की श्वास से प्रकट हुए हैं। अरेऽस्य ...
# 159  श्रीकृष्ण अर्जुन को बताते हैं कि उसे दिया जा र...
# 180   वास्तव में संसार के पदार्थ भगवान की माया शक्त...
# 274  हालांकि योगियों में कर्मयोगी, भक्ति योगी, अष्ट...
# 279  श्रीकृष्ण अब पूर्णतया भौतिक ज्ञान के क्षेत्र स...
# 300  यहाँ वे स्वयं को त्रिकालदर्शी घोषित करते हैं। ...
# 338  श्रीकृष्ण ने चौथे श्लोक से छठे श्लोक तक 'मत्स्...
# 385  अमरकोष (अति प्रतिष्ठित प्राचीन संस्कृत शब्द को...
# 386  श्रीकृष्ण स्पष्ट कहते हैं कि वे आत्मा से दूर न...
# 390  पुरोहित मंदिरों और घरों में धार्मिक कर्मकाण्ड,...
# 417   अर्जुन ने इस अध्याय के चौथे श्लोक में श्रीकृष...
# 431   सभी ओर प्रभु के असंख्य हाथ, टांगें, मुख और उद...
# 438  भगवान अपने सृजन, पालन और संहार की भव्य शक्ति क...
# 445  अर्जुन ने इस श्लोक में कस्माच्च तेन शब्द का प्...
# 446  अर्जुन श्रीकृष्ण को दिव्य सनातन पुरुष के रूप म...
# 453  भक्ति दो प्रकार की होती है-एक ऐश्वर्य भक्ति और...
# 462  इस श्लोक में भी श्रीकृष्ण इस पर बल देते हैं कि...
# 500  यहाँ श्रीकृष्ण विभिन्न प्रकार से भगवान की प्रभ...

# %% [markdown]
# ## Whole Embedding

# %%
kmeans_whole = KMeans(n_clusters=60, random_state=0).fit(verse_embeddings_whole)

# %%
def kmeans_whole_cluster(query_embedding_list):
    label=kmeans_whole.predict(query_embedding_list)[0]
    verse_index=[i for i in range(len(data)) if kmeans_whole.labels_[i]==label]
    return verse_index

# %%
verse_index=kmeans_whole_cluster(query_embedding_list)
data.loc[verse_index]
# Out:
#      Chapter  Verse                                              Sloke  \
# 215        5     17  तद्बुद्धयस्तदात्मानस्तन्निष्ठास्तत्परायणाः।\n\...
# 259        6     32  आत्मौपम्येन सर्वत्र समं पश्यति योऽर्जुन।\n\nसु...
# 541       14     24  समदुःखसुखः स्वस्थः समलोष्टाश्मकाञ्चनः।तुल्यप्र...
# 542       14     25  मानापमानयोस्तुल्यस्तुल्यो मित्रारिपक्षयोः।सर्व...
# 650       18     34  यया तु धर्मकामार्थान् धृत्या धारयतेऽर्जुन।प्रस...
# 655       18     39  यदग्रे चानुबन्धे च सुखं मोहनमात्मनः।निद्रालस्य...
#
#                                             Commentary
# 215   जिस प्रकार अज्ञानता के कारण कोई 'संसार' या 'ज...
# 259   हम मानते हैं कि शरीर के सभी अंग हमारे हैं और ...
# 541  भगवान के समान आत्मा भी तीनों गुणों से परे है। ...
# 542  भगवान के समान आत्मा भी तीनों गुणों से परे है। ...
# 650  दृढ़ता केवल योगियों में ही नहीं पायी जाती। सां...
# 655  तामसिक सुख निम्न कोटि के और प्रारंभ से अंत तक ...
